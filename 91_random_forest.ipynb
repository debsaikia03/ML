# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -2.248661 -1.488780 -1.385227  1.262516 -2.678478       0
# 1 -0.974184 -0.061549 -1.177162 -0.574264 -1.406311       0
# 2 -0.047506  0.172147  0.743168  0.603990 -1.463347       1
# 3 -0.452953  1.064467  0.390855 -0.372827 -2.744447       1
# 4 -1.312233  1.629752  1.657364  1.955087 -1.205070       1

# %%
# function for row sampling

def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
import random  # Import the random module

def sample_features(df, percent):
    # Randomly sample columns excluding the last column
    cols = random.sample(df.columns.tolist()[:-1], int(percent * (df.shape[1] - 1)))
    # Create a new DataFrame with the sampled columns
    new_df = df[cols]
    # Add the 'target' column to the new DataFrame
    new_df['target'] = df['target']
    return new_df

# %%
# function for combined sampling

def combined_sampling(df,row_percent,col_percent):
  new_df = sample_rows(df,row_percent)
  return sample_features(new_df,col_percent)

# %%
df1 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\debsa\AppData\Local\Temp\ipykernel_18720\1367835915.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
combined_sampling(df, 0.5,0.5)
# Out:
# C:\Users\debsa\AppData\Local\Temp\ipykernel_18720\1367835915.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
#         col3      col1  target
# 45 -0.025285 -1.937236       0
# 88 -0.149918 -2.774985       0
# 40  0.379525 -1.585894       0
# 49 -1.155770 -4.338602       0
# 11 -1.626825  1.937353       0
# 11 -1.626825  1.937353       0
# 83 -0.720426 -1.379503       0
# 64 -2.006012 -1.513038       0
# 85  0.811978 -0.885950       1
# 4   1.657364 -1.312233       1
# 99  0.639241 -0.731031       1
# 98  0.781235 -0.437671       1
# 15 -3.434315  0.751301       0
# 63  1.252061 -1.932266       1
# 53  1.586338 -1.843058       1
# 45 -0.025285 -1.937236       0
# 79 -0.606471 -0.656079       1
# ...

# %%
df2 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\debsa\AppData\Local\Temp\ipykernel_18720\1367835915.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\debsa\AppData\Local\Temp\ipykernel_18720\1367835915.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col1', 'col4', 'target'], dtype='object')
# Index(['col2', 'col5', 'target'], dtype='object')
# Index(['col3', 'col2', 'target'], dtype='object')

# %%
df3
# Out:
#         col3      col2  target
# 84  1.198154  0.693670       1
# 52  1.993961  2.196044       1
# 22  0.977979  1.008775       1
# 1  -1.177162 -0.061549       0
# 7  -1.750686  0.693075       0
# 13  0.699771  0.009054       1
# 44 -2.684865  0.974406       0
# 0  -1.385227 -1.488780       0
# 5   1.230076  0.734415       1
# 63  1.252061  2.072107       1
# 40  0.379525 -1.372315       0
# 48  1.608019  0.541405       1
# 0  -1.385227 -1.488780       0
# 95 -1.144357 -0.359675       0
# 67  3.027269  1.930584       1
# 1  -1.177162 -0.061549       0
# 52  1.993961  2.196044       1
# 66  1.852179  1.326326       1
# 26  1.981337  2.485921       1
# 99  0.639241  0.021572       1
# 31 -0.318207  0.287719       0
# 99  0.639241  0.021572       1
# 25 -1.471196 -2.055292       0
# 49 -1.155770 -2.045354       0
# 7  -1.750686  0.693075       0
# 91  2.157190  2.837985       1
# 32 -1.597063 -1.162773       0
# 39  1.199500  0.747843       1
# 1  -1.177162 -0.061549       0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf1)
# Out:
# [Text(0.53125, 0.9375, 'x[1] <= -0.377\ngini = 0.499\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.1875, 0.8125, 'x[1] <= -1.09\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.359375, 0.875, 'True  '),
#  Text(0.125, 0.6875, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.25, 0.6875, 'x[1] <= -0.918\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.125, 0.5625, 'x[1] <= -1.051\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0625, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1875, 0.4375, 'x[0] <= -1.02\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.125, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.375, 0.5625, 'x[1] <= -0.523\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.3125, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4375, 0.4375, 'x[0] <= -0.842\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.4, 0.9, 'x[0] <= -0.195\ngini = 0.497\nsamples = 50\nvalue = [23, 27]'),
#  Text(0.13333333333333333, 0.7, 'x[0] <= -0.85\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.26666666666666666, 0.8, 'True  '),
#  Text(0.06666666666666667, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.2, 0.5, 'x[0] <= -0.666\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.13333333333333333, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26666666666666666, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6666666666666666, 0.7, 'x[1] <= -2.528\ngini = 0.271\nsamples = 31\nvalue = [5, 26]'),
#  Text(0.5333333333333333, 0.8, '  False'),
#  Text(0.4666666666666667, 0.5, 'x[1] <= -4.091\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5333333333333333, 0.3, 'x[0] <= 0.671\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
# ...

# %%
clf1.predict(np.array([-0.025285,	-1.937236]).reshape(1,2))
# Out:
# C:\Users\debsa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-0.025285,	-1.937236]).reshape(1,2))
# Out:
# C:\Users\debsa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-0.025285,	-1.937236]).reshape(1,2))
# Out:
# C:\Users\debsa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
