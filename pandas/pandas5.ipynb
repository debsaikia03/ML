# %%
import numpy as np
import pandas as pd

food= pd.read_csv('food.csv')
food
# Out:
#       Name Gender       City Frequency      Item  Spends
# 0   Kavita      F      Patna     Daily     Pizza      68
# 1     Sita      M  Bangalore      Once     Fries      65
# 2   Kavita      F  Ahmedabad     Daily     Fries      50
# 3   Kavita      F      Delhi      Once    Burger      64
# 4     Neha      M    Chennai   Monthly     Fries      80
# ..     ...    ...        ...       ...       ...     ...
# 95  Kavita      F     Mumbai   Monthly     Pizza      27
# 96   Rahul      M     Mumbai    Weekly    Samosa      25
# 97    Sita      M    Gurgaon     Never    Paneer      17
# 98  Kavita      M    Kolkata     Never  Sandwich      25
# 99   Rohan      M       Pune   Monthly    Burger      43
#
# [100 rows x 6 columns]

# %%
food.pivot_table(index='City', columns='Item', values='Spends', aggfunc='mean')
# Out:
# Item       Burger  Fries  Ice Cream  Paneer  Pasta  Pizza      Salad  Samosa  \
# City
# Ahmedabad     NaN   50.0  16.000000    96.0   49.5   33.0  77.500000    81.0
# Bangalore     NaN   52.5  56.000000    59.0   13.0   69.0        NaN     NaN
# Chennai     55.00   54.5  67.666667    83.0    NaN   25.0  38.500000     NaN
# Delhi       56.50    NaN  52.500000    33.0   97.0   74.0        NaN     NaN
# Gurgaon     50.00    NaN  53.500000    41.5   55.5    NaN  36.000000    78.0
# Hyderabad     NaN   94.0        NaN     NaN    NaN    NaN  37.000000    30.5
# Kolkata     70.25   75.0  42.666667    76.0   33.0   55.0  19.000000     NaN
# Mumbai        NaN   34.0  34.500000    16.0    NaN   27.0  43.333333    25.0
# Patna       53.00   37.0        NaN     NaN    NaN   62.5        NaN     NaN
# Pune        49.00    NaN  48.000000    59.0   59.5    NaN  71.000000     NaN
#
# Item       Sandwich  Vada
# City
# Ahmedabad       NaN   NaN
# Bangalore       NaN   NaN
# Chennai        61.0   NaN
# ...

# %%
food.pivot_table(index=['City','Gender'], columns='Item', values='Spends', aggfunc='mean')
# Out:
# Item                 Burger  Fries  Ice Cream  Paneer  Pasta  Pizza  Salad  \
# City      Gender
# Ahmedabad F             NaN   50.0       16.0     NaN   31.0   33.0    NaN
#           M             NaN    NaN        NaN    96.0   68.0    NaN   77.5
# Bangalore F             NaN   40.0       86.0    81.0    NaN   59.0    NaN
#           M             NaN   65.0       26.0    37.0   13.0   79.0    NaN
# Chennai   F             NaN   29.0       72.0     NaN    NaN   25.0    NaN
#           M       55.000000   80.0       65.5    83.0    NaN    NaN   38.5
# Delhi     F       78.000000    NaN       52.5     NaN   97.0    NaN    NaN
#           M       35.000000    NaN        NaN    33.0    NaN   74.0    NaN
# Gurgaon   F       52.000000    NaN       53.5     NaN   88.0    NaN    NaN
#           M       48.000000    NaN        NaN    41.5   23.0    NaN   36.0
# Hyderabad F             NaN   94.0        NaN     NaN    NaN    NaN    NaN
# ...

# %%
food.pivot_table(index=['City','Gender'], columns=['Item','Frequency'], values='Spends', aggfunc='mean')
# Out:
# Item             Burger                            Fries                      \
# Frequency         Daily Monthly Never  Once Weekly Daily Monthly Never  Once
# City      Gender
# Ahmedabad F         NaN     NaN   NaN   NaN    NaN  50.0     NaN   NaN   NaN
#           M         NaN     NaN   NaN   NaN    NaN   NaN     NaN   NaN   NaN
# Bangalore F         NaN     NaN   NaN   NaN    NaN   NaN     NaN   NaN   NaN
#           M         NaN     NaN   NaN   NaN    NaN   NaN     NaN   NaN  65.0
# Chennai   F         NaN     NaN   NaN   NaN    NaN   NaN     NaN   NaN  29.0
#           M         NaN     NaN  55.0   NaN    NaN   NaN    80.0   NaN   NaN
# Delhi     F         NaN     NaN   NaN  78.0    NaN   NaN     NaN   NaN   NaN
#           M        39.0     NaN   NaN   NaN   31.0   NaN     NaN   NaN   NaN
# Gurgaon   F         NaN     NaN  52.0   NaN    NaN   NaN     NaN   NaN   NaN
#           M         NaN     NaN   NaN   NaN   48.0   NaN     NaN   NaN   NaN
# ...

# %%
match= pd.read_csv('matches.csv')
delivery= pd.read_csv('deliveries.csv')

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
mask= delivery['batsman_runs']==6
six= delivery[mask]
six.shape
# Out:
# (6523, 21)

# %%
pt= six.pivot_table(index='over', columns='batting_team', values='batsman_runs', aggfunc='count')
pt
# Out:
# batting_team  Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# over
# 1                             5.0              3.0              14.0
# 2                            17.0             21.0              19.0
# 3                            37.0             11.0              30.0
# 4                            34.0             17.0              41.0
# 5                            41.0             27.0              29.0
# 6                            43.0             22.0              27.0
# 7                            22.0             11.0              20.0
# 8                            25.0             13.0              26.0
# 9                            23.0             17.0              32.0
# 10                           23.0             14.0              24.0
# 11                           36.0             15.0              34.0
# 12                           36.0             26.0              38.0
# ...

# %%
#heatmap

# %%
import seaborn as sns

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='batting_team', ylabel='over'>

# %%
#corr function #co-relation fucntion #variance/co-variance

# %%
match.corr(numeric_only= True)
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.471087    0.024281    -0.010263       -0.015510
# season          0.471087  1.000000    0.004170    -0.016815       -0.000708
# dl_applied      0.024281  0.004170    1.000000    -0.010893       -0.011640
# win_by_runs    -0.010263 -0.016815   -0.010893     1.000000       -0.565181
# win_by_wickets -0.015510 -0.000708   -0.011640    -0.565181        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN

# %%
sns.heatmap(match.corr(numeric_only= True))
# Out:
# <Axes: >

# %%
#rename cols

# %%
match
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
match.rename(columns={'city':'place','date':'dom'},inplace=True)
match
# Out:
#       id  season      place         dom                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# set_index() & reset_index()

# %%
match.set_index('id',inplace=True)
match
# Out:
#      index  season      place         dom                        team1  \
# id
# 1        0    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2        1    2017       Pune  2017-04-06               Mumbai Indians
# 3        2    2017     Rajkot  2017-04-07                Gujarat Lions
# 4        3    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5        4    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...        ...         ...                          ...
# 632    631    2016     Raipur  2016-05-22             Delhi Daredevils
# 633    632    2016  Bangalore  2016-05-24                Gujarat Lions
# 634    633    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 635    634    2016      Delhi  2016-05-27                Gujarat Lions
# 636    635    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# id
# ...

# %%
match.reset_index(inplace=True)
match
# Out:
#      index   id  season      place         dom                        team1  \
# 0        0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        1    2    2017       Pune  2017-04-06               Mumbai Indians
# 2        2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3        3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4        4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...  ...     ...        ...         ...                          ...
# 631    631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632    632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633    633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634    634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635    635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
# ...

# %%
match['winner'].value_counts().reset_index() #converts series to dataframe
# Out:
#                          winner  count
# 0                Mumbai Indians     92
# 1           Chennai Super Kings     79
# 2         Kolkata Knight Riders     77
# 3   Royal Challengers Bangalore     73
# 4               Kings XI Punjab     70
# 5              Rajasthan Royals     63
# 6              Delhi Daredevils     62
# 7           Sunrisers Hyderabad     42
# 8               Deccan Chargers     29
# 9                 Gujarat Lions     13
# 10                Pune Warriors     12
# 11       Rising Pune Supergiant     10
# 12         Kochi Tuskers Kerala      6
# 13      Rising Pune Supergiants      5
