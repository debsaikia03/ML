# %%
#dropping missing data using dropna()

# %%
import numpy as np
import pandas as pd

data= pd.read_csv('titanic.csv')
data
# Out:
#     PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0             1         0       3    Passenger 1  female   5.0      3      0
# 1             2         1       2    Passenger 2  female  37.0      0      0
# 2             3         0       2    Passenger 3  female  53.0      0      1
# 3             4         0       2    Passenger 4  female  68.0      2      1
# 4             5         0       2    Passenger 5  female  21.0      1      0
# ..          ...       ...     ...            ...     ...   ...    ...    ...
# 95           96         1       1   Passenger 96    male  51.0      0      1
# 96           97         1       2   Passenger 97    male  23.0      1      0
# 97           98         1       1   Passenger 98  female  14.0      2      1
# 98           99         1       1   Passenger 99  female  18.0      2      0
# 99          100         0       2  Passenger 100    male  20.0      0      2
#
#         Ticket    Fare     Cabin Embarked
# ...

# %%
data.shape
# Out:
# (100, 12)

# %%
data.dropna()
# Out:
#     PassengerId  Survived  Pclass          Name     Sex   Age  SibSp  Parch  \
# 2             3         0       2   Passenger 3  female  53.0      0      1
# 5             6         1       2   Passenger 6  female  11.0      3      2
# 6             7         0       2   Passenger 7  female  55.0      2      1
# 11           12         0       1  Passenger 12  female  27.0      2      0
# 32           33         1       3  Passenger 33    male  68.0      2      1
# 42           43         1       1  Passenger 43  female  78.0      1      0
# 43           44         1       3  Passenger 44    male  17.0      2      2
# 44           45         1       1  Passenger 45  female  19.0      1      1
# 47           48         0       3  Passenger 48    male  80.0      1      0
# 58           59         0       3  Passenger 59  female  48.0      0      1
# 62           63         0       1  Passenger 63  female  35.0      3      2
# ...

# %%
data.dropna().shape
# Out:
# (17, 12)

# %%
data.dropna(how='all').shape #remove entry where a row is all NaN
# Out:
# (100, 12)

# %%
data.dropna(axis=1) #remove all columns where it contains even 1 missing value
# Out:
#     PassengerId  Survived  Pclass           Name     Sex  SibSp  Parch
# 0             1         0       3    Passenger 1  female      3      0
# 1             2         1       2    Passenger 2  female      0      0
# 2             3         0       2    Passenger 3  female      0      1
# 3             4         0       2    Passenger 4  female      2      1
# 4             5         0       2    Passenger 5  female      1      0
# ..          ...       ...     ...            ...     ...    ...    ...
# 95           96         1       1   Passenger 96    male      0      1
# 96           97         1       2   Passenger 97    male      1      0
# 97           98         1       1   Passenger 98  female      2      1
# 98           99         1       1   Passenger 99  female      2      0
# 99          100         0       2  Passenger 100    male      0      2
#
# [100 rows x 7 columns]

# %%
data.dropna(axis=1).shape #12 -> 7
# Out:
# (100, 7)

# %%
data.dropna(axis=1, how='all').shape ##remove that column where it contains all missing values in that column
# Out:
# (100, 12)

# %%
data.dropna(subset=['Cabin']).shape
# Out:
# (22, 12)

# %%
data.dropna(subset=['Cabin','Embarked']).shape
# Out:
# (19, 12)

# %%
#fillna() -> filling missing values

# %%
data
# Out:
#     PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0             1         0       3    Passenger 1  female   5.0      3      0
# 1             2         1       2    Passenger 2  female  37.0      0      0
# 2             3         0       2    Passenger 3  female  53.0      0      1
# 3             4         0       2    Passenger 4  female  68.0      2      1
# 4             5         0       2    Passenger 5  female  21.0      1      0
# ..          ...       ...     ...            ...     ...   ...    ...    ...
# 95           96         1       1   Passenger 96    male  51.0      0      1
# 96           97         1       2   Passenger 97    male  23.0      1      0
# 97           98         1       1   Passenger 98  female  14.0      2      1
# 98           99         1       1   Passenger 99  female  18.0      2      0
# 99          100         0       2  Passenger 100    male  20.0      0      2
#
#         Ticket    Fare     Cabin Embarked
# ...

# %%
data.fillna(0)
# Out:
#     PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0             1         0       3    Passenger 1  female   5.0      3      0
# 1             2         1       2    Passenger 2  female  37.0      0      0
# 2             3         0       2    Passenger 3  female  53.0      0      1
# 3             4         0       2    Passenger 4  female  68.0      2      1
# 4             5         0       2    Passenger 5  female  21.0      1      0
# ..          ...       ...     ...            ...     ...   ...    ...    ...
# 95           96         1       1   Passenger 96    male  51.0      0      1
# 96           97         1       2   Passenger 97    male  23.0      1      0
# 97           98         1       1   Passenger 98  female  14.0      2      1
# 98           99         1       1   Passenger 99  female  18.0      2      0
# 99          100         0       2  Passenger 100    male  20.0      0      2
#
#         Ticket    Fare     Cabin Embarked
# ...

# %%
data['Cabin'].fillna('Not Specified', inplace=True) #apply individuak column
data
# Out:
#     PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0             1         0       3    Passenger 1  female   5.0      3      0
# 1             2         1       2    Passenger 2  female  37.0      0      0
# 2             3         0       2    Passenger 3  female  53.0      0      1
# 3             4         0       2    Passenger 4  female  68.0      2      1
# 4             5         0       2    Passenger 5  female  21.0      1      0
# ..          ...       ...     ...            ...     ...   ...    ...    ...
# 95           96         1       1   Passenger 96    male  51.0      0      1
# 96           97         1       2   Passenger 97    male  23.0      1      0
# 97           98         1       1   Passenger 98  female  14.0      2      1
# 98           99         1       1   Passenger 99  female  18.0      2      0
# 99          100         0       2  Passenger 100    male  20.0      0      2
#
# ...

# %%
data['Age'] = data['Age'].bfill()
data
# Out:
#     PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0             1         0       3    Passenger 1  female   5.0      3      0
# 1             2         1       2    Passenger 2  female  37.0      0      0
# 2             3         0       2    Passenger 3  female  53.0      0      1
# 3             4         0       2    Passenger 4  female  68.0      2      1
# 4             5         0       2    Passenger 5  female  21.0      1      0
# ..          ...       ...     ...            ...     ...   ...    ...    ...
# 95           96         1       1   Passenger 96    male  51.0      0      1
# 96           97         1       2   Passenger 97    male  23.0      1      0
# 97           98         1       1   Passenger 98  female  14.0      2      1
# 98           99         1       1   Passenger 99  female  18.0      2      0
# 99          100         0       2  Passenger 100    male  20.0      0      2
#
# ...

# %%
data['Age'] = data['Age'].ffill()
data
# Out:
#     PassengerId  Survived  Pclass           Name     Sex   Age  SibSp  Parch  \
# 0             1         0       3    Passenger 1  female   5.0      3      0
# 1             2         1       2    Passenger 2  female  37.0      0      0
# 2             3         0       2    Passenger 3  female  53.0      0      1
# 3             4         0       2    Passenger 4  female  68.0      2      1
# 4             5         0       2    Passenger 5  female  21.0      1      0
# ..          ...       ...     ...            ...     ...   ...    ...    ...
# 95           96         1       1   Passenger 96    male  51.0      0      1
# 96           97         1       2   Passenger 97    male  23.0      1      0
# 97           98         1       1   Passenger 98  female  14.0      2      1
# 98           99         1       1   Passenger 99  female  18.0      2      0
# 99          100         0       2  Passenger 100    male  20.0      0      2
#
# ...
